# %%
import folium
mapit = folium.Map( )


folium.CircleMarker(location=[25.197587, 55.2741737],
                        fill_color="#065535",
                        radius=100,
                        popup = "Emaar Boulevera 1",
                        weight=3).add_to(mapit)

folium.CircleMarker(location=[25.19771, 55.27441],
                        fill_color="#f40059",
                        radius=100,
                        popup = "Armani Mediterraneo2",
                        weight=3).add_to(mapit)

mapit.fit_bounds(mapit.get_bounds())
mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import numpy as np;
data=pd.read_csv('/home/osman/Data/data.tsv', delimiter='\t' ,index_col = False)
data.columns = ['time','v_id','type','route','latitude','longitude']
route=pd.read_csv('/home/osman/Data/route_to_stops_count.tsv', delimiter='\t')
route.columns = ['type','route','n_stops']
debug=pd.read_csv('/home/osman/Data/debug.tsv', delimiter='\t')
debug.columns = ['type','route','latitude','longitude']
route
# Out:
#         type  route  n_stops
# 0        bus     55       60
# 1        bus    198       49
# 2        bus     98       36
# 3        bus    107       41
# 4        bus     37       69
# 5        bus    220       36
# 6        bus    174       51
# 7        bus    179       43
# 8        bus    116       29
# 9        bus    115       43
# 10       bus    172       32
# 11       bus    171       46
# 12       bus    135       21
# 13       bus     34       42
# 14       bus    191       16
# 15       bus    149       40
# 16       bus    178       18
# 17       bus    222       57
# 18       bus    221       24
# 19       bus    200       57
# 20       bus    203       28
# 21       bus    143       19
# 22       bus    165       45
# 23       bus    150       62
# 24       bus    153       33
# 25       bus    105       45
# 26       bus     92       22
# 27       bus     12       82
# 28   tramway     11       36
# 29   tramway      3       56
# ..       ...    ...      ...
# ...

# %%
# Out:
# array([[50.527863, 50.955353],
#        [50.504898, 50.936607],
#        [50.527637, 50.955616],
#        ...,
#        [50.50579 , 50.969734],
#        [50.505733, 50.968227],
#        [50.504993, 50.967827]], dtype=float32)

# %%
d86.drop_duplicates(keep=False, inplace=False)
# Out:
#    type  route   latitude  longitude
# 0   bus     86  50.504160  50.955193
# 1   bus     86  50.504610  50.943245
# 2   bus     86  50.505506  50.936145
# 3   bus     86  50.509442  50.936353
# 4   bus     86  50.515003  50.936669
# 5   bus     86  50.520787  50.938007
# 6   bus     86  50.524135  50.941164
# 7   bus     86  50.524002  50.947514
# 8   bus     86  50.522820  50.955576
# 9   bus     86  50.527595  50.955701
# 10  bus     86  50.530601  50.958406
# 11  bus     86  50.530455  50.965748
# 12  bus     86  50.530275  50.974591
# 13  bus     86  50.532046  50.980081
# 14  bus     86  50.530251  50.987940
# 15  bus     86  50.529416  50.998036
# 16  bus     86  50.531806  51.003014
# 17  bus     86  50.531796  51.007415
# 18  bus     86  50.531804  51.012662
# 19  bus     86  50.531773  51.020720
# 20  bus     86  50.531773  51.028121
# 21  bus     86  50.531755  51.037130
# 22  bus     86  50.532399  51.049338
# 23  bus     86  50.531952  51.045869
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [time, v_id, type, route, latitude, longitude]
# Index: []

# %%
# Out:
#           latitude  longitude
# 169181   50.527862  50.955354
# 169199   50.504898  50.936607
# 169207   50.527637  50.955615
# 169251   50.503956  50.959354
# 169283   50.531860  51.002317
# 169340   50.530281  50.977002
# 169344   50.531849  51.012971
# 169346   50.531830  51.027339
# 170692   50.532974  51.049171
# 170702   50.533355  51.047479
# 170709   50.531929  51.044982
# 170735   50.532013  51.001844
# 170844   50.524021  50.938054
# 170847   50.524090  50.947593
# 170855   50.527637  50.955615
# 170881   50.532013  51.001844
# 170890   50.531292  51.015775
# 170892   50.531849  51.018869
# 170901   50.531810  51.037254
# 170977   50.530334  50.974153
# 170978   50.530334  50.974153
# 171048   50.506050  50.969816
# 171091   50.524021  50.938054
# 171106   50.527637  50.955615
# 171151   50.531357  51.017362
# 171209   50.532009  51.001729
# 171249   50.523864  50.949706
# 171285   50.506008  50.969894
# 171302   50.509166  50.936195
# 171316   50.524021  50.938054
# ...

# %%
import folium
b=b86[['latitude','longitude']] 
ave_lat = b.latitude.mean()
ave_lon = b.longitude.mean()
map_osm = folium.Map(location=[ave_lat, ave_lon], zoom_start=11)
data.apply(lambda row:folium.CircleMarker(location=[row["Latitude"], row["Longitude"]], 
                                              radius=10)
                                             .add_to(map_osm), axis='index')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/tester/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index._bin_search()
#
# TypeError: '<' not supported between instances of 'numpy.ndarray' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ...

# %%
# Out:
# 50.52102755804749

# %%
b.latitude
# Out:
# 169181     50.527862
# 169199     50.504898
# 169207     50.527637
# 169251     50.503956
# 169283     50.531860
# 169340     50.530281
# 169344     50.531849
# 169346     50.531830
# 170692     50.532974
# 170702     50.533355
# 170709     50.531929
# 170735     50.532013
# 170844     50.524021
# 170847     50.524090
# 170855     50.527637
# 170881     50.532013
# 170890     50.531292
# 170892     50.531849
# 170901     50.531810
# 170977     50.530334
# 170978     50.530334
# 171048     50.506050
# 171091     50.524021
# 171106     50.527637
# 171151     50.531357
# 171209     50.532009
# 171249     50.523864
# 171285     50.506008
# 171302     50.509166
# 171316     50.524021
#              ...
# 1010244    50.530368
# 1010249    50.532154
# 1010267    50.531849
# 1010269    50.531524
# 1010284    50.531788
# 1010287    50.533111
# 1010294    50.532386
# 1010297    50.531925
# 1010310    50.532135
# 1010311    50.532524
# 1010312    50.532009
# 1010337    50.530254
# ...
